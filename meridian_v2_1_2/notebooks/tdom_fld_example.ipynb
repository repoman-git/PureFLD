# %% [markdown]
# # FLD + TDOM Example

# %%
import pandas as pd
from meridian_v2_1_2.seasonality import compute_tdom_flags
df=pd.read_csv('data/gc_sample.csv',parse_dates=['date']).set_index('date')
tdom=compute_tdom_flags(df.index,[1,2,3,4,5],[])
tdom
